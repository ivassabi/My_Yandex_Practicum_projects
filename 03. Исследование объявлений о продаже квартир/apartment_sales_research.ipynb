# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Изучение-данных-из-файла" data-toc-modified-id="Шаг-1.-Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Изучение данных из файла</a></span></li><li><span><a href="#Шаг-2.-Предобработка-данных" data-toc-modified-id="Шаг-2.-Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2. Предобработка данных</a></span></li><li><span><a href="#Шаг-3.-Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Шаг-3.-Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-и-добавим-в-таблицу-цену-квадратного-метра" data-toc-modified-id="Посчитаем-и-добавим-в-таблицу-цену-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Посчитаем и добавим в таблицу цену квадратного метра</a></span></li><li><span><a href="#Добавим-в-таблицу-день-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="Добавим-в-таблицу-день-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Добавим в таблицу день недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Добавим-в-таблицу-этаж-квартиры;-варианты-—-первый,-последний,-другой" data-toc-modified-id="Добавим-в-таблицу-этаж-квартиры;-варианты-—-первый,-последний,-другой-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Добавим в таблицу этаж квартиры; варианты — первый, последний, другой</a></span></li><li><span><a href="#Посчитаем-и-добавим-в-таблицу-соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей" data-toc-modified-id="Посчитаем-и-добавим-в-таблицу-соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Посчитаем и добавим в таблицу соотношение жилой и общей площади, а также отношение площади кухни к общей</a></span></li></ul></li><li><span><a href="#Шаг-4.-EDA" data-toc-modified-id="Шаг-4.-EDA-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Шаг 4. EDA</a></span><ul class="toc-item"><li><span><a href="#Изучите-слелующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра" data-toc-modified-id="Изучите-слелующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучите слелующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра</a></span></li><li><span><a href="#Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго." data-toc-modified-id="Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго.</a></span></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили." data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.</a></span></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.</a></span></li><li><span><a href="#Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-(locality_name).-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-(locality_name).-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.</a></span></li><li><span><a href="#Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?" data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?</a></span></li></ul></li><li><span><a href="#Общий-вывод:" data-toc-modified-id="Общий-вывод:-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод:</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости.
# **Цель исследования**: установить параметры, которые помогут научиться определять рыночную стоимость объектов недвижимости. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Описание данных**
#
# - `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м);
# - `balcony` — число балконов;
# - `ceiling_height` — высота потолков (м);
# - `cityCenters_nearest` — расстояние до центра города (м);
# - `days_exposition` — сколько дней было размещено объявление (от публикации до снятия);
# - `first_day_exposition` — дата публикации;
# - `floor` — этаж;
# - `floors_total` — всего этажей в доме;
# - `is_apartment` — апартаменты (булев тип);
# - `kitchen_area` — площадь кухни в квадратных метрах (м²);
# - `last_price` — цена на момент снятия с публикации;
# - `living_area` — жилая площадь в квадратных метрах (м²);
# - `locality_name` — название населённого пункта;
# - `open_plan` — свободная планировка (булев тип);
# - `parks_around3000` — число парков в радиусе 3 км;
# - `parks_nearest` — расстояние до ближайшего парка (м);
# - `ponds_around3000` — число водоёмов в радиусе 3 км;
# - `ponds_nearest` — расстояние до ближайшего водоёма (м);
# - `rooms` — число комнат;
# - `studio` — квартира-студия (булев тип);
# - `total_area` — площадь квартиры в квадратных метрах (м²);
# - `total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# ## Шаг 1. Изучение данных из файла

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'C:\\Users\\79119\\Desktop\\DF\\appartment_sales\\real_estate_data.csv', sep='\t')

# %% [markdown]
# Посмотрим на первые строки таблицы и общую информацию.

# %%
def df_info(df):
    print('Ознакомление с файлом:')
    display(df.head())
    print(' ')
    print('Общая информация:')
    print(df.info())

# %%
df_info(df)
# Out:
# Ознакомление с файлом:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# **Вывод:**
#
# Нам предоставлена таблица, состоящая из 23699 строк и 22 столбцов. Типы данных в столбцах: bool(2), float64(14), int64(3), object(3). Также присутсвует большое количество пропусков.

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %% [markdown]
# Переименуем столбец, чтобы не выбивался из общей концепции

# %%
df = df.rename(columns={'cityCenters_nearest': 'city_centers_nearest'})

# %% [markdown]
# Посчитаем количество пропусков в каждом столбце.

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Удалим пропуски в 'locality_name' и в 'floors_total', в связи с тем, что невозможно установить природу их появления (их доля менее 1%)

# %%
df = df.dropna(subset = ['locality_name', 'floors_total'])
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9084
# floors_total                0
# living_area              1865
# floor                       0
# is_apartment            20805
# studio                      0
# open_plan                   0
# kitchen_area             2222
# balcony                 11475
# locality_name               0
# airports_nearest         5524
# city_centers_nearest     5501
# parks_around3000         5500
# parks_nearest           15535
# ponds_around3000         5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %% [markdown]
# Уберем все лишние слова из названий населенных пунктов и приведем все к нижнему регистру. Задел на проверку на дубликаты

# %%
df['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
remove_words = ["поселок", "посёлок", "городского", "городской", "типа", "село", "деревня", "товарищество", "коттеджный"]
pat = '|'.join(remove_words)
df['locality_name'] = (
    df['locality_name'].str.lower()
    .replace(pat,'', regex=True)
    .apply(lambda x: x.strip())
)
df['locality_name'].unique()
# Out:
# array(['санкт-петербург', 'шушары', 'янино-1', 'парголово', 'мурино',
#        'ломоносов', 'сертолово', 'петергоф', 'пушкин', 'кудрово',
#        'коммунар', 'колпино', 'красный бор', 'гатчина', 'фёдоровское',
#        'выборг', 'кронштадт', 'кировск', 'новое девяткино',
#        'металлострой', 'лебяжье', 'сиверский', 'молодцово',
#        'кузьмоловский', 'садовое  новая ропша', 'павловск', 'пикколово',
#        'всеволожск', 'волхов', 'кингисепп', 'приозерск', 'сестрорецк',
#        'куттузи', 'аннино', 'ефимовский', 'плодовое', 'заклинье',
#        'торковичи', 'первомайское', 'красное', 'понтонный', 'сясьстрой',
#        'старая', 'лесколово', 'новый свет', 'сланцы', 'путилово',
#        'ивангород', 'шлиссельбург', 'никольское', 'зеленогорск',
#        'сосновый бор', 'оржицы', 'кальтино', 'романовка', 'бугры',
#        'рощино', 'кириши', 'луга', 'волосово', 'отрадное', 'павлово',
#        'оредеж', 'копорье', 'молодёжное', 'тихвин', 'победа', 'нурма',
# ...

# %% [markdown]
# Заполним пропуски в стобце 'is_apartment' значенем False. Предположительно эти данные не были заполнены в связи с тем, что помещение не является аппартаментами.

# %%
df['is_apartment'] = df['is_apartment'].fillna(False)
df['is_apartment'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним пропуски в 'balcony' нулями. Предположительно: нет информации о балконе, значит нет балкона.

# %%
df['balcony'] = df['balcony'].fillna(0)
df['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним пропуски в 'living_area' медианным значением, сгруппированым по 'total_area' и 'rooms'

# %%
df['living_area'] = (
    df['living_area']
    .fillna(df.groupby(['total_area', 'rooms'])['living_area']
    .transform('median'))
)
df['living_area'] = df['living_area'].fillna(df['living_area'].median())
df['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заполним пропуски в столбце с площадью кухни разницей между общей и жилой площадьми.

# %%
df['kitchen_area'] = df['kitchen_area'].fillna(df['total_area'] - df['living_area'])
df['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Осуществим проверку: не вышло ли так, что сумма кухни и жилой площади превышают значение общей площади. Для этого создадим временную колонку, где будет сумма жилой площади и кухни и сравним со значением в колонке с общей площадью

# %%
df['chek'] = df['living_area'] + df['kitchen_area']

# %%
df[['total_area', 'chek']].query('chek > total_area')
# Out:
#        total_area   chek
# 184         30.20  32.30
# 545         23.80  25.00
# 551         31.59  39.83
# 601         53.70  55.30
# 696         34.69  46.86
# ...           ...    ...
# 21956       46.00  52.00
# 21993       31.48  40.00
# 22277       38.35  40.30
# 22554       31.65  38.70
# 23202       67.92  76.04
#
# [87 rows x 2 columns]

# %%
df = df.drop('chek', axis=1)

# %% [markdown]
# 87 строк, где сумма превысила значение общей площади. Т.к. это менее одного процента данных, эти строки не повлияют на результат дальнейшего исследования. В связи с этим оставим их без изменения.

# %% [markdown]
# Заполним пропуски в 'ceiling_height' медианным значением, сгруппированым по 'floors_total'

# %%
df['ceiling_height'] = (
    df['ceiling_height']
    .fillna(df.groupby('floors_total')['ceiling_height']
    .transform('median'))
)
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())
df['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# Приведем столбец 'first_day_exposition' к формату datetime

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
df.dtypes
# Out:
# total_images                     int64
# last_price                     float64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                   float64
# living_area                    float64
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                        float64
# locality_name                   object
# airports_nearest               float64
# city_centers_nearest           float64
# parks_around3000               float64
# parks_nearest                  float64
# ponds_around3000               float64
# ponds_nearest                  float64
# days_exposition                float64
# dtype: object

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.75          11.0         18.6      1         False   False
# 2            2.55           5.0         34.3      4         False   False
# 3            2.60          14.0         54.0      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Приведем столбец `floors_total` к целочисленному типу.

# %%
df['floors_total'] = df['floors_total'].astype('int64')

# %% [markdown]
# Проверим на дубликаты

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5524
# city_centers_nearest     5501
# parks_around3000         5500
# parks_nearest           15535
# ponds_around3000         5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %% [markdown]
# В столбцах parks_nearest и ponds_nearest очень большое количество пропусков. Их заполнение может привести к искажению данных. Также я не стала трогать столбцы parks_around3000, ponds_around3000 и airports_nearest. Эти данные не участвую в дальшейшем исследовании.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  float64
# ...

# %%
df['days_exposition'].agg(['min', 'max'])
# Out:
# min       1.0
# max    1580.0
# Name: days_exposition, dtype: float64

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# **Вывод:**
#
# 1. Названия столбцов приведены к единому стилю.
# 2. Были удалены пропуски с признаках 'locality_name' и 'floors_total'.
# 3. Заполнены пропуски в столбцах: 'is_apartment', 'balcony', 'living_area', 'kitchen_area' и 'ceiling_height'.
# 4. Столбец 'first_day_exposition' приведен к формату даты, а 'floors_total' к целочисленному типу.

# %% [markdown]
# ## Шаг 3. Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Посчитаем и добавим в таблицу цену квадратного метра

# %%
df['price_per_m2'] = np.round(df['last_price']/df['total_area'],2)
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.75            11         18.6      1         False   False
# 2            2.55             5         34.3      4         False   False
# 3            2.60            14         54.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# ### Добавим в таблицу день недели, месяц и год публикации объявления

# %%
for col in ['year', 'month', 'weekday']:
     exec('df["' + col + '"] = df["first_day_exposition"].dt.' + col)
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.75            11         18.6      1         False   False
# 2            2.55             5         34.3      4         False   False
# 3            2.60            14         54.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# ### Добавим в таблицу этаж квартиры; варианты — первый, последний, другой

# %%
df['room_floor'] = 'другой'
df.loc[df['floor'] == 1, 'room_floor'] = 'первый'
df.loc[df['floor'] == df['floors_total'], 'room_floor'] = 'последний'
df['room_floor'].unique()
# Out:
# array(['другой', 'первый', 'последний'], dtype=object)

# %% [markdown]
# ### Посчитаем и добавим в таблицу соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
df['ratio_living_to_total'] = np.round(df['living_area']/df['total_area'], 2)
df['ratio_kitchen_to_total'] = np.round(df['kitchen_area']/df['total_area'], 2)
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.75            11         18.6      1         False   False
# 2            2.55             5         34.3      4         False   False
# 3            2.60            14         54.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# **Вывод:**
#
# В ходе исследования были добавлены следующие признаки:
# 1. цена за м2
# 2. день недели, месяц и год публикации объявления
# 3. этажность квартир по категориям: первый, последний и другой
# 4. соотношение жилой площади к общей площади
# 5. соотношение площади кухни к общей площади

# %% [markdown]
# ## Шаг 4. EDA

# %% [markdown]
# ###  Изучите слелующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра

# %%
df[['total_area', 'last_price', 'rooms', 'ceiling_height']].describe()
# Out:
#          total_area    last_price         rooms  ceiling_height
# count  23565.000000  2.356500e+04  23565.000000    23565.000000
# mean      60.322824  6.540058e+06      2.070656        2.735737
# std       35.657060  1.091093e+07      1.078591        0.996999
# min       12.000000  1.219000e+04      0.000000        1.000000
# 25%       40.000000  3.400000e+06      1.000000        2.550000
# 50%       52.000000  4.646000e+06      2.000000        2.650000
# 75%       69.700000  6.790000e+06      3.000000        2.750000
# max      900.000000  7.630000e+08     19.000000      100.000000

# %% [markdown]
# Как видно из вышепредставленной таблицы, присутствуют аномально большие значения в столбцах: с общей площадью (900 м2), квартиры с количеством комнат 19 шт и в столбце со значениями высоты потолка (100 м)

# %%
print('Количество квартир с общей площадью более 500 м2:', df[df['total_area'] >= 500]['rooms'].count())
# Out:
# Количество квартир с общей площадью более 500 м2: 9

# %%
df['last_price'].agg(['min', 'max'])
# Out:
# min        12190.0
# max    763000000.0
# Name: last_price, dtype: float64

# %%
print('Количество квартир дороже 300 млн.', df[df['last_price'] >= 300000000]['rooms'].count())
print('Количество квартир дешевле 500 тыс.', df[df['last_price'] < 500000]['rooms'].count())
# Out:
# Количество квартир дороже 300 млн. 5
# Количество квартир дешевле 500 тыс. 14

# %%
last_price = df.pivot_table(index=('total_area', 'city_centers_nearest'), values = 'last_price').reset_index()
last_price[last_price['last_price']>=300000000]
# Out:
#        total_area  city_centers_nearest   last_price
# 17291       190.0                1197.0  330000000.0
# 17522       400.0                3956.0  763000000.0
# 17524       401.0                2389.0  401300000.0
# 17542       618.0                5297.0  300000000.0
# 17545       900.0                7877.0  420000000.0

# %% [markdown]
# Все квартиры, стоимостью свыше 300 млн. имеют большую площадь и расположены недалеко от центра.

# %%
df['rooms'].value_counts().sort_values(ascending=False)
# Out:
# 1     8004
# 2     7897
# 3     5779
# 4     1172
# 5      325
# 0      194
# 6      104
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 15       1
# 19       1
# 16       1
# 12       1
# Name: rooms, dtype: int64

# %% [markdown]
# Одна- и двух- и трехкомнатные квартиры лидируют по количеству предложений на рынке. Но и присутствуют вартиры с 19 комнатами. Выбор на любой вкус

# %%
print('Количество квартир с высотой потолков свыше 6 м:', 
      df[df['ceiling_height']>6]['ceiling_height'].count())
print('Количество квартир с высотой потолков ниже 2 м:',
       df[df['ceiling_height'] < 2]['ceiling_height'].count())
# Out:
# Количество квартир с высотой потолков свыше 6 м: 30
# Количество квартир с высотой потолков ниже 2 м: 3

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.histplot(data=df, x = 'total_area', bins=100)
plt.xlim(0, 300)
plt.xticks(np.arange(0, 300, step=10), rotation=90)
plt.grid(True)
plt.title('Распределение по общей площади')
plt.xlabel('Общая площадь')
plt.ylabel('Количество квартир')

plt.subplot(2,2,2)
sns.histplot(data=df, x = 'last_price', bins=1000, color='green')
plt.xlim(0, 30000000)
plt.xticks(np.arange(0, 30000000, step=1000000), rotation=90)
plt.grid(True)
plt.title('Распределение по стоимости')
plt.xlabel('Стоимость')
plt.ylabel('Количество квартир')

plt.subplot(2, 2, 3)
sns.histplot(data=df, x = 'rooms', bins=50, color= 'violet')
plt.xticks(np.arange(0, 10, step=1))
plt.xlim(0,10)
plt.title('Распределение комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Количество квартир')

plt.subplot(2, 2, 4)
sns.histplot(data=df, x= 'ceiling_height', bins=1000, color= 'orange')
plt.xticks(np.arange(0, 15, step=.25))
plt.xlim(2,5)
plt.title('Распределение высоты потоков')
ax3 = plt.xlabel('Высота потолка')
ax3 = plt.ylabel('Количество квартир')

# %% [markdown]
# **Вывод:**
#
# 1. Общая площадь: разброс значений от 12 до 900 м2. Колиечтво квартир с аномально большой площадью (более 500 м2) составляет 9 шт.  Наибольшее количество предложений по квартирам с площадью от 30 до 65 м2
# 2. Стоимость: значения стоимости варьируются от 12 т. до 763 млн. В хвостах: 14 предложений менее 500 тыс и 5 квартир стоимостью свыше 300 млн. Такая высокая стоимость может быть обусловлена очень большой площадью и близким расположением к центру. Наибольшее количество предложений попадает в вилку от 3 до 5,5 млн.
# 3. Количество комнат: разброс значений от 0 (вероятнее всего студии) до 19 комнат. Причем всего 11 предложений, с количеством комнат равным или более 10. Наибольшее количество объявлений - это одна-, двух- и трехкомнатные квартиры.
# 4. Высота потолков: разброс значений от 1 до 100 м. В хвостах: 3 квартиры с высотой потолков менее 2 м и 30 свыше 6 м. Наибольшее количество объявлений на квартиры с высотой потолков от 2,5 до 2,75 м
# 5. Возможно в аномально большие значения по ошибке попали коммерческие помещения.

# %% [markdown]
# ### Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго.

# %%
df['days_exposition'].describe()
# Out:
# count    20394.000000
# mean       180.741395
# std        219.732782
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.histplot(data=df, x= 'days_exposition')
plt.xticks(np.arange(0, 1600, step = 100))
plt.grid(True)
plt.title('Длительность размещения объявления')
plt.xlabel('Количество дней')
plt.ylabel('Количество объявлений')
# Out:
# Text(0, 0.5, 'Количество объявлений')

# %%
print('Количество квартир, срок продажи которых менее 30 дней:', 
      df[df['days_exposition'] < 30]['days_exposition'].count())
print('Количество квартир, срок подажи которых более года', 
     df[df['days_exposition'] > 365]['days_exposition'].count())
print('Количество квартир, которые попадают в вилку до 3х месяцев:',
     df.query('0 < days_exposition < 90')['days_exposition'].count())
# Out:
# Количество квартир, срок продажи которых менее 30 дней: 3516
# Количество квартир, срок подажи которых более года 3042
# Количество квартир, которые попадают в вилку до 3х месяцев: 9686

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   total_images            23565 non-null  int64
#  1   last_price              23565 non-null  float64
#  2   total_area              23565 non-null  float64
#  3   first_day_exposition    23565 non-null  datetime64[ns]
#  4   rooms                   23565 non-null  int64
#  5   ceiling_height          23565 non-null  float64
#  6   floors_total            23565 non-null  int64
#  7   living_area             23565 non-null  float64
#  8   floor                   23565 non-null  int64
#  9   is_apartment            23565 non-null  bool
#  10  studio                  23565 non-null  bool
#  11  open_plan               23565 non-null  bool
#  12  kitchen_area            23565 non-null  float64
#  13  balcony                 23565 non-null  float64
# ...

# %% [markdown]
# **Вывод:**
#
# Более 40% всех объявлений попадают в период продажи до 3х месяцев, из которых 36% это продажи сроком менее 1 месяца. 3042 объявления  - это квартиры, срок продажи которых более 1 года.

# %% [markdown]
# ### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %% [markdown]
# Еще раз посмотрим статистику. Ранее уже были описаны выбивающиеся значения. Проверим их еще раз на графике boxplot.

# %%
df[['total_area', 'rooms', 'ceiling_height']].describe()
# Out:
#          total_area         rooms  ceiling_height
# count  23565.000000  23565.000000    23565.000000
# mean      60.322824      2.070656        2.735737
# std       35.657060      1.078591        0.996999
# min       12.000000      0.000000        1.000000
# 25%       40.000000      1.000000        2.550000
# 50%       52.000000      2.000000        2.650000
# 75%       69.700000      3.000000        2.750000
# max      900.000000     19.000000      100.000000

# %%
plt.figure(figsize=(15, 10))

plt.subplot(2, 3, 1)
sns.boxplot(x = df['total_area'])
plt.xlim(0, 400)
plt.title('Общая площадь')

plt.subplot(2, 3, 2)
sns.boxplot(x = df['rooms'], color='green')
plt.title('Количество комнат')

plt.subplot(2, 3, 3)
sns.boxplot(x = df['ceiling_height'], color='red')
plt.xlim(0, 10)
plt.title('Высота потолков')
plt.show()

# %%
df[df['total_area'] > 350]['total_area'].count()
# Out:
# 41

# %% [markdown]
# Основываясь на исследованиях, проведенных в п. 4.1 и изучив вышепредставленные графики, было принято решения избавиться от следующих данных:
# 1. Явно, что площадь более 350 м2 - это анамально большое значение, для жилой квартиры. Таких объявлений у нас 41 шт.
# 2. Более 10 комнат, тоже не свойственно для квартир.
# 3. Объявления с квартирами, высота потолков которых более 6 метров - удаляем.
# 4. Также стоимость менее 500000 является аномально низкой для данного региона. От этих данных тоже избавимся.

# %%
df2 = df.copy()
df2 = df2.query('total_area <= 350 and last_price > 500000 and rooms < 10 and ceiling_height < 7')

# %%
df2[['total_area', 'rooms', 'ceiling_height', 'last_price']].describe()
# Out:
#          total_area         rooms  ceiling_height    last_price
# count  23469.000000  23469.000000    23469.000000  2.346900e+04
# mean      59.610255      2.060378        2.706427  6.354252e+06
# std       31.298516      1.039067        0.233123  8.107528e+06
# min       12.000000      0.000000        1.000000  5.200000e+05
# 25%       40.000000      1.000000        2.550000  3.400000e+06
# 50%       52.000000      2.000000        2.650000  4.630000e+06
# 75%       69.500000      3.000000        2.750000  6.750000e+06
# max      347.500000      9.000000        6.000000  3.300000e+08

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23469 entries, 0 to 23698
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   total_images            23469 non-null  int64
#  1   last_price              23469 non-null  float64
#  2   total_area              23469 non-null  float64
#  3   first_day_exposition    23469 non-null  datetime64[ns]
#  4   rooms                   23469 non-null  int64
#  5   ceiling_height          23469 non-null  float64
#  6   floors_total            23469 non-null  int64
#  7   living_area             23469 non-null  float64
#  8   floor                   23469 non-null  int64
#  9   is_apartment            23469 non-null  bool
#  10  studio                  23469 non-null  bool
#  11  open_plan               23469 non-null  bool
#  12  kitchen_area            23469 non-null  float64
#  13  balcony                 23469 non-null  float64
# ...

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.heatmap(data=df2[['price_per_m2', 'total_area']].corr(), annot=True)
plt.title('Зависимость стоимости за м2 и площади')

plt.subplot(1, 2, 2)
sns.scatterplot(y = df2['price_per_m2'], x = df2['total_area'], alpha= .3)
plt.show()

# %% [markdown]
# Присутствует очень слабая связь между стоимостью м2 и величиной общей площади. Как видно на диаграмме расеяния, присутствует снижение стимости м2 после 150 м2.

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.heatmap(data=df2[['price_per_m2', 'rooms']].corr(), annot=True)
plt.title('Зависимость стоимости за м2 от количества комнат')

plt.subplot(1, 2, 2)
sns.barplot(data= df2.pivot_table(index= 'rooms', values = 'price_per_m2', aggfunc='median')
            .reset_index(), x = 'rooms', y = 'price_per_m2')

display(df2.pivot_table(index= 'rooms', values = 'price_per_m2', aggfunc='median')
            .sort_values('price_per_m2', ascending=False).reset_index())
# Out:
#    rooms  price_per_m2
# 0      7    107329.485
# 1      8    106187.050
# 2      0    105078.205
# 3      1    100000.000
# 4      6     99370.650
# 5      5     96286.110
# 6      2     92814.370
# 7      4     92636.990
# 8      3     88983.050
# 9      9     82057.740

# %% [markdown]
# Не обнаружено прямой зависимости между стоимость м2 и количеством комнат. Как видно из диаграммы, наибольшей стоимость м2 обладают квартиры с количеством комнат 7, 8, 0, 1

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.heatmap(data=df2[['price_per_m2', 'city_centers_nearest']].corr(), annot=True)
plt.title('Зависимость стоимости за м2 от удаленности от центра')

plt.subplot(1, 2, 2)
sns.scatterplot(y = df2['price_per_m2'], x = df2['city_centers_nearest'], alpha= .3, color='green')
plt.show()

# %% [markdown]
# Прямой зависимости нет, но на диаграмме расеяния видно, что стоимость м2 больше у квартир, удаленность которых не привышает 10 км

# %%
sns.barplot(data= df2.pivot_table(index='room_floor', values= 'last_price', aggfunc='median').reset_index(),
            x= 'room_floor', y= 'last_price')
plt.title('Стоимость квартир в зависимости от этажа ')

display(df2.pivot_table(index='room_floor', values= 'last_price', aggfunc='median').reset_index())
# Out:
#   room_floor  last_price
# 0     другой   4835000.0
# 1     первый   3900000.0
# 2  последний   4300000.0

# %% [markdown]
# Стоимость на первом и последнем этажах квартир меньше, чем на других этажах. Первый этаж самый недорогой, последний - чуть дороже и самые дорогие квартиры между первым и последним этажами.

# %%
df2.pivot_table(index = 'year', values = 'price_per_m2', aggfunc = 'median').plot(grid=True)
plt.title('Изменеие стоимости за м2 по годам')
plt.show()

# %% [markdown]
# Начиная с 2017г. начинается значительный рост стоимости вкадратного метра площади

# %%
df2.pivot_table(index = ('month'), values = 'price_per_m2', aggfunc = 'median').plot(grid=True)
plt.title('Изменеие стоимости за м2 в течение года по месяцам')
plt.xticks(np.arange(1, 12, step=1))
plt.show()

# %% [markdown]
# Пик роста цен за м2 приходятся на апрель, август и ноябрь. Наиболее низкие цены в мае и июне.

# %%
df2.pivot_table(index = ('weekday'), values = 'price_per_m2', aggfunc = 'median').plot(grid=True)

plt.show()

# %% [markdown]
# Пиковые значения во вторник и среду, по субботам самая низкая цена.

# %% [markdown]
# **Вывод:**
#
# 1. На стоимость за м2 влияет удаленность от центра.
# 2. Также на стоимость квартиры влияет этаж (квартиры на первом и последнем этаже стоят чуть дешевле)
# 3. Повышение цены за м 2 наблюдается с 2017г, в апреле, августе и ноябре по средам и вторникам.

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %%
city_list = df2['locality_name'].value_counts().head(10).reset_index()
city_list
# Out:
#              index  locality_name
# 0  санкт-петербург          15586
# 1           мурино            584
# 2          кудрово            470
# 3           шушары            439
# 4       всеволожск            398
# 5           пушкин            367
# 6          колпино            338
# 7        парголово            327
# 8          гатчина            306
# 9           выборг            237

# %%
top10 = df2.query('locality_name in ["санкт-петербург", "мурино", "кудрово", "шушары", "всеволожск", "парголово", "колпино", "пушкин", "гатчина", "выборг"]')

sns.barplot(data= top10.groupby('locality_name')['price_per_m2'].agg('median')
            .reset_index().sort_values('price_per_m2', ascending=False),
            x= 'locality_name', y= 'price_per_m2')
plt.xticks(rotation=90)
plt.title('Рейтинг городов по стоимости за м2')
plt.show()

# %% [markdown]
# **Вывод:**
#
# Из диаграрммы видно, что г. Санкт-Петербург лидирует по стоимости за квадратный метр жилья среди самых популярных населенных пунков, на 10 месте находится г. Выборг

# %% [markdown]
# ### Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %%
city_centers_nearest = df2.copy()

# %% [markdown]
# Выделила в переменную city_centers_nearest ненулевые значения 'city_centers_nearest'

# %%
city_centers_nearest = city_centers_nearest[city_centers_nearest['city_centers_nearest'].notnull()]
city_centers_nearest.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.75            11         18.6      1         False   False
# 2            2.55             5         34.3      4         False   False
# 3            2.60            14         54.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Добавим столбец с расстоянием до центра в км

# %%
city_centers_nearest['city_centers_nearest_km'] = (
    city_centers_nearest['city_centers_nearest']/1000
).astype('int64')
city_centers_nearest.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16         51.0      8         False   False
# 1            2.75            11         18.6      1         False   False
# 2            2.55             5         34.3      4         False   False
# 3            2.60            14         54.0      9         False   False
# 4            3.03            14         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Посчитаем среднюю цену для каждого км

# %%
distance = city_centers_nearest.pivot_table(
    index = 'city_centers_nearest_km', values = 'price_per_m2'
).reset_index()
distance.head(10)
# Out:
#    city_centers_nearest_km   price_per_m2
# 0                        0  188313.545765
# 1                        1  166835.830717
# 2                        2  143710.411382
# 3                        3  126097.865772
# 4                        4  137030.204226
# 5                        5  145619.923742
# 6                        6  152021.370258
# 7                        7  140673.011634
# 8                        8  119858.668283
# 9                        9  110178.371064

# %%
distance.plot(x = 'city_centers_nearest_km', y = 'price_per_m2', grid=True)
plt.show()

# %% [markdown]
# **Вывод:**
#
# Судя по графику пик стоимости приходится на расстоянии примерно 3 км. Будем считать за цент диаметр в 3 кв.

# %% [markdown]
# ### Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %%
df3 = df2.copy()

# %%
df3 = city_centers_nearest.query('city_centers_nearest_km <= 3')

# %%
df3[['total_area', 'price_per_m2', 'rooms', 'ceiling_height']].describe()
# Out:
#         total_area  price_per_m2        rooms  ceiling_height
# count  1144.000000  1.144000e+03  1144.000000     1144.000000
# mean     94.945402  1.438404e+05     3.046329        3.075009
# std      48.862837  1.114797e+05     1.383108        0.378837
# min      12.000000  2.891963e+04     0.000000        2.450000
# 25%      62.000000  9.500000e+04     2.000000        2.817500
# 50%      83.400000  1.160879e+05     3.000000        3.000000
# 75%     114.350000  1.489007e+05     4.000000        3.285000
# max     347.000000  1.736842e+06     8.000000        5.800000

# %% [markdown]
# Для центра города характерны: площадь квартир 93 м2, число комнат 3, высота потолков 3 м и цена за м2 в районе 138425 руб.

# %%
df3.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition', 'price_per_m2', 'year', 'month',
#        'weekday', 'room_floor', 'ratio_living_to_total',
#        'ratio_kitchen_to_total', 'city_centers_nearest_km'],
#       dtype='object')

# %%
test2 = df3.pivot_table(index = ['rooms', 'floor', 'city_centers_nearest_km', 'first_day_exposition'],
                        values='price_per_m2').reset_index()
test2.head()
# Out:
#    rooms  floor  city_centers_nearest_km first_day_exposition  price_per_m2
# 0      0      1                        2           2017-12-10     131250.00
# 1      0      1                        2           2018-07-13     135593.22
# 2      0      1                        3           2017-12-08      94608.70
# 3      0      2                        3           2018-08-22     136563.88
# 4      0      5                        1           2017-07-21     115492.96

# %%
pd.plotting.scatter_matrix(test2, figsize=(9, 9))
plt.show()

# %%
sns.heatmap(data = test2.corr(), annot=True)
plt.title('Зависимость параметров квартир, расположенных в центре города')
plt.show()

# %% [markdown]
# **Вывод:**
#
# Картина по квартирам в центре города достаточно однородна, нет таких явных заисимостей, как для объявлений собранных по всему городу и его окресностей.

# %% [markdown]
# ## Общий вывод:
#
# 1. Для исследования нам предоставлена таблица, состоящая из 23699 строк и 22 столбцов. Типы данных в столбцах: bool(2), float64(14), int64(3), object(3). Также присутсвует большое количество пропусков.
# 2. Была проведена следующая предобработка данных:
#     - Названия столбцов приведены к единому стилю.
#     - Были удалены пропуски с признаках 'locality_name' и 'floors_total'.
#     - Заполнены пропуски в столбцах: 'is_apartment', 'balcony', 'living_area', 'kitchen_area' и 'ceiling_height'.
#     - Столбец 'first_day_exposition' приведен к формату даты, а 'floors_total' к целочисленному типу.
# 3. В ходе исследования были добавлены следующие признаки:
#     - цена за м2
#     - день недели, месяц и год публикации объявления
#     - этажность квартир по категориям: первый, последний и другой
#     - соотношение жилой площади к общей площади
#     - соотношение площади кухни к общей площади
# 4.  Изучив параметры: площадь, цена, число комнат и высоту потолков, можно сделать следующие выводы:
#     - Общая площадь: разброс значений от 12 до 900 м2. Колиечтво квартир с аномально большой площадью (более 500 м2) составляет 9 шт.  Наибольшее количество предложений по квартирам с площадью от 30 до 65 м2
#     - Стоимость: значения стоимости варьируются от 12 т. до 763 млн. В хвостах: 14 предложений менее 500 тыс и 5 квартир стоимостью свыше 300 млн. Такая высокая стоимость может быть обусловлена очень большой площадью и близким расположением к центру. Наибольшее количество предложений попадает в вилку от 3 до 5,5 млн.
#     - Количество комнат: разброс значений от 0 (вероятнее всего студии) до 19 комнат. Причем всего 11 предложений, с количеством комнат равным или более 10. Наибольшее количество объявлений - это одна-, двух- и трехкомнатные квартиры.
#     - Высота потолков: разброс значений от 1 до 100 м. В хвостах: 3 квартиры с высотой потолков менее 2 м и 30 свыше 6 м. Наибольшее количество объявлений на квартиры с высотой потолков от 2,5 до 2,75 м
#     - Возможно в аномально большие значения по ошибке попали коммерческие помещения.
# 5. Касаемо времени продажи квартир: более 40% всех объявлений попадают в период продажи до 3х месяцев, из которых 36% это продажи сроком менее 1 месяца. 3042 объявления  - это квартиры, срок продажи которых более 1 года.
# 6. Были удалены следующие выбросы:
#     - Явно, что площадь более 350 м2 - это анамально большое значение, для жилой квартиры. Таких объявлений у нас 41 шт.
#     - Более 10 комнат, тоже не свойственно для квартир.
#     - Объявления с квартирами, высота потолков которых более 6 метров - удаляем.
#     - Также стоимость менее 500000 является аномально низкой для данного региона. От этих данных тоже избавимся.
# 7. Были установлены 10 населенных пунктов с наибольшим числом объявлений:  г. Санкт-Петербург лидирует по стоимости за квадратный метр жилья среди самых популярных населенных пунков, на 10 месте находится г. Выборг
# 8. Посчитали цену для каждого км и выявили, что радиус центра составляет 3 км.
# 9. Проанализировали след параметры у квартир, находящихся в центре: площадь, цена, число комнат и высота потолков и пришли к выводу, что в первую очередь на формирование цены за м2 влияют такие факторы, как: удаленность от центра, количество комнат и общая площадь. Также сказывается этаж, на котором квартира размещена. Чем больше выборка объявлений, тем более явными становятся данные факторы.
